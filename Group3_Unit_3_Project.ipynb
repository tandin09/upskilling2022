# %% [markdown]
# <a href="https://colab.research.google.com/github/tandin09/upskilling2022/blob/main/Group3_Unit_3_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Covid 19 Data Analysis

# %%
# environment set up
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
Covid_df = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv') # open raw data and opty th link

# %%
Covid_df
# Out:
#                date      county       state     fips  cases  deaths
# 0        2020-01-21   Snohomish  Washington  53061.0      1     0.0
# 1        2020-01-22   Snohomish  Washington  53061.0      1     0.0
# 2        2020-01-23   Snohomish  Washington  53061.0      1     0.0
# 3        2020-01-24        Cook    Illinois  17031.0      1     0.0
# 4        2020-01-24   Snohomish  Washington  53061.0      1     0.0
# ...             ...         ...         ...      ...    ...     ...
# 2115626  2022-01-14  Sweetwater     Wyoming  56037.0   8859   112.0
# 2115627  2022-01-14       Teton     Wyoming  56039.0   8057    14.0
# 2115628  2022-01-14       Uinta     Wyoming  56041.0   4522    34.0
# 2115629  2022-01-14    Washakie     Wyoming  56043.0   1961    41.0
# 2115630  2022-01-14      Weston     Wyoming  56045.0   1291    16.0
#
# [2115631 rows x 6 columns]

# %%
type(Covid_df)
# Out:
# pandas.core.frame.DataFrame

# %%
Covid_df.shape
# Out:
# (2115631, 6)

# %%
Covid_df.columns
# Out:
# Index(['date', 'county', 'state', 'fips', 'cases', 'deaths'], dtype='object')

# %%
Covid_df.isnull().sum()
# Out:
# date          0
# county        0
# state         0
# fips      19538
# cases         0
# deaths    48323
# dtype: int64

# %%
columns_to_be_dropped = ['flips'] 
type(columns_to_be_dropped)
# Out:
# list

# %%
Covid_df.describe()
# Out:
#                fips         cases        deaths
# count  2.096093e+06  2.115631e+06  2.067308e+06
# mean   3.138427e+04  7.464286e+03  1.364403e+02
# std    1.633638e+04  3.407305e+04  7.404164e+02
# min    1.001000e+03  0.000000e+00  0.000000e+00
# 25%    1.901900e+04  2.690000e+02  4.000000e+00
# 50%    3.000900e+04  1.339000e+03  2.600000e+01
# 75%    4.610900e+04  4.437000e+03  8.200000e+01
# max    7.803000e+04  2.172712e+06  3.650900e+04

# %% [markdown]
# New York Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
Covid_df_2 = Covid_df[Covid_df['county'] == 'New York City']

Covid_df_2
# Out:
#                date         county     state  fips    cases   deaths
# 416      2020-03-01  New York City  New York   NaN        1      0.0
# 448      2020-03-02  New York City  New York   NaN        1      0.0
# 482      2020-03-03  New York City  New York   NaN        2      0.0
# 518      2020-03-04  New York City  New York   NaN        2      0.0
# 565      2020-03-05  New York City  New York   NaN        4      0.0
# ...             ...            ...       ...   ...      ...      ...
# 2101251  2022-01-10  New York City  New York   NaN  1949382  35906.0
# 2104502  2022-01-11  New York City  New York   NaN  1978014  36089.0
# 2107753  2022-01-12  New York City  New York   NaN  2005338  36224.0
# 2111005  2022-01-13  New York City  New York   NaN  2038543  36374.0
# 2114257  2022-01-14  New York City  New York   NaN  2058308  36509.0
#
# [685 rows x 6 columns]

# %%
Covid_df_2.isnull().sum()
# Out:
# date        0
# county      0
# state       0
# fips      685
# cases       0
# deaths      0
# dtype: int64

# %%
Covid_df_3 = Covid_df_2.tail(30)

Covid_df_3
# Out:
#                date         county     state  fips    cases   deaths
# 2019985  2021-12-16  New York City  New York   NaN  1209454  35020.0
# 2023236  2021-12-17  New York City  New York   NaN  1219276  35045.0
# 2026487  2021-12-18  New York City  New York   NaN  1219276  35045.0
# 2029738  2021-12-19  New York City  New York   NaN  1237462  35066.0
# 2032988  2021-12-20  New York City  New York   NaN  1249755  35067.0
# 2036238  2021-12-21  New York City  New York   NaN  1267713  35100.0
# 2039488  2021-12-22  New York City  New York   NaN  1284470  35126.0
# 2042737  2021-12-23  New York City  New York   NaN  1302298  35151.0
# 2045987  2021-12-24  New York City  New York   NaN  1317511  35151.0
# 2049237  2021-12-25  New York City  New York   NaN  1317511  35151.0
# 2052487  2021-12-26  New York City  New York   NaN  1372339  35151.0
# 2055737  2021-12-27  New York City  New York   NaN  1394411  35200.0
# 2058986  2021-12-28  New York City  New York   NaN  1430241  35204.0
# ...

# %%
Covid_df_3.isnull().sum()
# Out:
# date       0
# county     0
# state      0
# fips      30
# cases      0
# deaths     0
# dtype: int64

# %%
Covid_df.iloc[482]
# Out:
# date         2020-03-03
# county    New York City
# state          New York
# fips                NaN
# cases                 2
# deaths                0
# Name: 482, dtype: object

# %%
Covid_df_4 = Covid_df_2[Covid_df_2['date'] == '2022-01-12']
Covid_df_4
# Out:
#                date         county     state  fips    cases   deaths
# 2107753  2022-01-12  New York City  New York   NaN  2005338  36224.0

# %%
Covid_df_5 = Covid_df_2[Covid_df_2['date'] == '2021-12-11']

Covid_df_5
# Out:
#                date         county     state  fips    cases   deaths
# 2003731  2021-12-11  New York City  New York   NaN  1183680  34956.0

# %%
sns.relplot(data=Covid_df_3, x="cases", y="deaths")

# %%
sns.lmplot(data=Covid_df_3, x="cases", y="deaths")

# %%
sns.countplot(x='cases', data=Covid_df_3)

# %%
sns.countplot(x='deaths', data=Covid_df_3)

# %%
Covid_df_3.shape
# Out:
# (30, 6)

# %%
Covid_df_3.describe()
# Out:
#        fips         cases        deaths
# count   0.0  3.000000e+01     30.000000
# mean    NaN  1.569469e+06  35473.266667
# std     NaN  2.876939e+05    424.806482
# min     NaN  1.209454e+06  35020.000000
# 25%     NaN  1.306101e+06  35151.000000
# 50%     NaN  1.526649e+06  35365.500000
# 75%     NaN  1.812710e+06  35765.500000
# max     NaN  2.058308e+06  36509.000000

# %%
new_Covid_3 = Covid_df_3[['cases', 'deaths']]

new_Covid_3
# Out:
#            cases   deaths
# 2019985  1209454  35020.0
# 2023236  1219276  35045.0
# 2026487  1219276  35045.0
# 2029738  1237462  35066.0
# 2032988  1249755  35067.0
# 2036238  1267713  35100.0
# 2039488  1284470  35126.0
# 2042737  1302298  35151.0
# 2045987  1317511  35151.0
# 2049237  1317511  35151.0
# 2052487  1372339  35151.0
# 2055737  1394411  35200.0
# 2058986  1430241  35204.0
# 2062235  1463101  35304.0
# 2065485  1503957  35349.0
# 2068736  1549341  35382.0
# 2071987  1594682  35402.0
# 2075238  1630332  35448.0
# 2078489  1668333  35463.0
# 2081741  1697200  35514.0
# 2084993  1737167  35605.0
# 2088245  1779501  35683.0
# 2091496  1823779  35793.0
# 2094748  1871370  35793.0
# 2098000  1914011  35883.0
# 2101251  1949382  35906.0
# 2104502  1978014  36089.0
# 2107753  2005338  36224.0
# 2111005  2038543  36374.0
# 2114257  2058308  36509.0

# %%
new_Covid_3.plot(kind = 'scatter', x = 'cases', y = 'deaths')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
sns.barplot(x= "cases", y= "deaths", data=new_Covid_3)

# %% [markdown]
# California Data

# %%
Cali_Covid_df = Covid_df[Covid_df['county'] == 'Los Angeles']

Cali_Covid_df
# Out:
#                date       county       state    fips    cases   deaths
# 9        2020-01-26  Los Angeles  California  6037.0        1      0.0
# 14       2020-01-27  Los Angeles  California  6037.0        1      0.0
# 19       2020-01-28  Los Angeles  California  6037.0        1      0.0
# 24       2020-01-29  Los Angeles  California  6037.0        1      0.0
# 29       2020-01-30  Los Angeles  California  6037.0        1      0.0
# ...             ...          ...         ...     ...      ...      ...
# 2099580  2022-01-10  Los Angeles  California  6037.0  2011668  27798.0
# 2102831  2022-01-11  Los Angeles  California  6037.0  2046912  27812.0
# 2106082  2022-01-12  Los Angeles  California  6037.0  2087285  27850.0
# 2109333  2022-01-13  Los Angeles  California  6037.0  2132227  27985.0
# 2112585  2022-01-14  Los Angeles  California  6037.0  2172712  27985.0
#
# [720 rows x 6 columns]

# %%
Cali_Covid_df_2 = Cali_Covid_df.tail(30)

Cali_Covid_df_2
# Out:
#                date       county       state    fips    cases   deaths
# 2018313  2021-12-16  Los Angeles  California  6037.0  1554070  27388.0
# 2021564  2021-12-17  Los Angeles  California  6037.0  1557389  27413.0
# 2024815  2021-12-18  Los Angeles  California  6037.0  1561081  27432.0
# 2028066  2021-12-19  Los Angeles  California  6037.0  1564583  27441.0
# 2031317  2021-12-20  Los Angeles  California  6037.0  1567837  27448.0
# 2034567  2021-12-21  Los Angeles  California  6037.0  1570934  27473.0
# 2037817  2021-12-22  Los Angeles  California  6037.0  1577406  27488.0
# 2041067  2021-12-23  Los Angeles  California  6037.0  1586017  27512.0
# 2044316  2021-12-24  Los Angeles  California  6037.0  1595943  27533.0
# 2047566  2021-12-25  Los Angeles  California  6037.0  1595943  27533.0
# 2050816  2021-12-26  Los Angeles  California  6037.0  1616737  27546.0
# 2054066  2021-12-27  Los Angeles  California  6037.0  1624146  27555.0
# ...

# %%
Cali_Covid_df_3 = Cali_Covid_df_2[Cali_Covid_df_2['date'] == '2022-01-13']

Cali_Covid_df_3
# Out:
#                date       county       state    fips    cases   deaths
# 2109333  2022-01-13  Los Angeles  California  6037.0  2132227  27985.0

# %%
Cali_Covid_df_4 = Cali_Covid_df_2[Cali_Covid_df_2['date'] == '2021-12-15']

Cali_Covid_df_4
# Out:
# Empty DataFrame
# Columns: [date, county, state, fips, cases, deaths]
# Index: []

# %%
Cali_Covid_df_2.describe()

# %%
sns.countplot(x='cases', data=Cali_Covid_df_2)

# %%
sns.countplot(x='deaths', data=Cali_Covid_df_2)

# %% [markdown]
# California vs New York Last 30 Days

# %%
sns.lmplot(data=Cali_Covid_df_2, x= "cases", y= "deaths")

sns.lmplot(data=Covid_df_3, x= "cases", y= "deaths")

# %%
New_County_df = pd.concat([Covid_df_3, Cali_Covid_df_2])

New_County_df
# Out:
#                date         county       state    fips    cases   deaths
# 2019985  2021-12-16  New York City    New York     NaN  1209454  35020.0
# 2023236  2021-12-17  New York City    New York     NaN  1219276  35045.0
# 2026487  2021-12-18  New York City    New York     NaN  1219276  35045.0
# 2029738  2021-12-19  New York City    New York     NaN  1237462  35066.0
# 2032988  2021-12-20  New York City    New York     NaN  1249755  35067.0
# 2036238  2021-12-21  New York City    New York     NaN  1267713  35100.0
# 2039488  2021-12-22  New York City    New York     NaN  1284470  35126.0
# 2042737  2021-12-23  New York City    New York     NaN  1302298  35151.0
# 2045987  2021-12-24  New York City    New York     NaN  1317511  35151.0
# 2049237  2021-12-25  New York City    New York     NaN  1317511  35151.0
# 2052487  2021-12-26  New York City    New York     NaN  1372339  35151.0
# 2055737  2021-12-27  New York City    New York     NaN  1394411  35200.0
# ...

# %%
sns.lmplot(data=New_County_df, x='cases', y='deaths', hue='county')

# %% [markdown]
# Utah Data

# %%
Utah_Covid_df = Covid_df[Covid_df['county'] == 'Utah']

Utah_Covid_df
# Out:
#                date county state     fips   cases  deaths
# 2687     2020-03-15   Utah  Utah  49049.0       1     0.0
# 3157     2020-03-16   Utah  Utah  49049.0       1     0.0
# 3693     2020-03-17   Utah  Utah  49049.0       1     0.0
# 4325     2020-03-18   Utah  Utah  49049.0       2     0.0
# 5081     2020-03-19   Utah  Utah  49049.0       3     0.0
# ...             ...    ...   ...      ...     ...     ...
# 2102280  2022-01-10   Utah  Utah  49049.0  156867   670.0
# 2105531  2022-01-11   Utah  Utah  49049.0  158633   671.0
# 2108782  2022-01-12   Utah  Utah  49049.0  160261   676.0
# 2112034  2022-01-13   Utah  Utah  49049.0  162824   678.0
# 2115286  2022-01-14   Utah  Utah  49049.0  164808   678.0
#
# [671 rows x 6 columns]

# %%
Utah_Covid_df_2 = Utah_Covid_df.tail(30)

Utah_Covid_df_2
# Out:
#                date county state     fips   cases  deaths
# 2021014  2021-12-16   Utah  Utah  49049.0  140861   635.0
# 2024265  2021-12-17   Utah  Utah  49049.0  141121   637.0
# 2027516  2021-12-18   Utah  Utah  49049.0  141121   637.0
# 2030767  2021-12-19   Utah  Utah  49049.0  141121   637.0
# 2034017  2021-12-20   Utah  Utah  49049.0  141688   642.0
# 2037267  2021-12-21   Utah  Utah  49049.0  141845   646.0
# 2040517  2021-12-22   Utah  Utah  49049.0  142085   650.0
# 2043766  2021-12-23   Utah  Utah  49049.0  142317   651.0
# 2047016  2021-12-24   Utah  Utah  49049.0  142317   651.0
# 2050266  2021-12-25   Utah  Utah  49049.0  142317   651.0
# 2053516  2021-12-26   Utah  Utah  49049.0  142317   651.0
# 2056765  2021-12-27   Utah  Utah  49049.0  143029   653.0
# 2060014  2021-12-28   Utah  Utah  49049.0  143282   653.0
# 2063264  2021-12-29   Utah  Utah  49049.0  143886   655.0
# 2066514  2021-12-30   Utah  Utah  49049.0  144502   656.0
# ...

# %%
sns.countplot(x='cases', data=Utah_Covid_df_2)

# %%
sns.countplot(x='deaths', data=Utah_Covid_df_2)

# %%
Utah_Covid_df_3 = Utah_Covid_df_2[Utah_Covid_df_2['date'] == '2022-01-13']

Utah_Covid_df_3
# Out:
#                date county state     fips   cases  deaths
# 2112034  2022-01-13   Utah  Utah  49049.0  162824   678.0

# %%
Utah_Covid_df_4 = Utah_Covid_df_2[Utah_Covid_df_2['date'] == '2021-12-15']

Utah_Covid_df_4
# Out:
# Empty DataFrame
# Columns: [date, county, state, fips, cases, deaths]
# Index: []

# %% [markdown]
# Utah vs New York & California Last 30 Days

# %%
sns.lmplot(data=Utah_Covid_df_2, x= 'cases', y= 'deaths', hue='state')

sns.lmplot(data=Covid_df_3, x= 'cases', y= 'deaths', hue='state')

sns.lmplot(data=Cali_Covid_df_2, x= 'cases', y= 'deaths', hue='state')

# %% [markdown]
# Conclusion
#
# The conclusion we draw from this project with all these graphs that have flawed.
# The total confirm cases, the number of deaths; all these values we had in dataset on the last 30 days shows how the Covid_19 has been spread over the last 30 days.
# The number of has rising in almost all the counties we work on.
# The big number of cases are actually very much for New York, California, Utah and they are rising again.
